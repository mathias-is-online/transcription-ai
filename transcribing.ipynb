# %%
# Importa las bibliotecas necesarias
import os
import whisper

# Definir la clase o las funciones que contienen tu lógica
class ANALISIS_AUDIO:
    def __init__(self):
        # Puedes inicializar variables aquí si es necesario
        pass

    def transcribir_audio(self, audio_file_path, language="es"):
        try:
            model = whisper.load_model("large")
            print("En transcribir_audio, la ruta es: " + audio_file_path)
            result = model.transcribe("audio.mp3", language=language,fp16=False)
            return result["text"]
        except FileNotFoundError:
            print(f"Error: El archivo no se pudo encontrar en la ruta {audio_file_path}")
            return None  # Puedes manejar este retorno como desees



    def transcribir_audios_masivo(self, audio_folder, txt_folder):
        print("Hola amigos")
        for filename in os.listdir(audio_folder):
            print("El filename es:   " + filename)
            audio_file_path = os.path.join(audio_folder, filename)
            print("EL AUDIO FILE PATH QUE SE USA EN LA TRANSCRIPCION ES:  " + audio_file_path)
            transcription = self.transcribir_audio(audio_file_path)
            text_filename = os.path.splitext(filename)[0] + ".txt"
            text_file_path = os.path.join(txt_folder, text_filename)
            with open(text_file_path, "w", encoding="utf-8") as text_file:
                print('Transcripción  : ' + transcription)
                text_file.write(transcription)

# Crear una instancia de la clase
analisis = ANALISIS_AUDIO()

# Definir las rutas a las carpetas de audio y texto
audio_folder = r"C:\Users\mathi\Downloads\transcribe\AUDIO"
txt_folder = r"C:\Users\mathi\Downloads\transcribe\TEXTO"




# Llamar a la función para transcribir archivos masivos
#analisis.transcribir_audios_masivo(audio_folder, txt_folder)
# Escoge un archivo específico de la carpeta
audio_file_path = os.path.join(audio_folder, 'audio-test.mp3')
analisis.transcribir_audio(audio_file_path)
# Out:
# En transcribir_audio, la ruta es: C:\Users\mathi\Downloads\transcribe\AUDIO\audio-test.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 50
#      46 # Llamar a la función para transcribir archivos masivos
#      47 #analisis.transcribir_audios_masivo(audio_folder, txt_folder)
#      48 # Escoge un archivo específico de la carpeta
#      49 audio_file_path = os.path.join(audio_folder, 'audio-test.mp3')
# ---> 50 analisis.transcribir_audio(audio_file_path)
#
# Cell In[2], line 15, in ANALISIS_AUDIO.transcribir_audio(self, audio_file_path, language)
#      13     model = whisper.load_model("large")
#      14     print("En transcribir_audio, la ruta es: " + audio_file_path)
# ---> 15     result = model.transcribe("audio.mp3", language=language,fp16=False)
#      16     return result["text"]
#      17 except FileNotFoundError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\transcribe.py:279, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
#     276 mel_segment = pad_or_trim(mel_segment, N_FRAMES).to(model.device).to(dtype)
#     278 decode_options["prompt"] = all_tokens[prompt_reset_since:]
# --> 279 result: DecodingResult = decode_with_fallback(mel_segment)
#     280 tokens = torch.tensor(result.tokens)
#     282 if no_speech_threshold is not None:
#     283     # no voice activity check
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\transcribe.py:195, in transcribe.<locals>.decode_with_fallback(segment)
#     192     kwargs.pop("best_of", None)
#     194 options = DecodingOptions(**kwargs, temperature=t)
# --> 195 decode_result = model.decode(segment, options)
#     197 needs_fallback = False
#     198 if (
#     199     compression_ratio_threshold is not None
#     200     and decode_result.compression_ratio > compression_ratio_threshold
#     201 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\decoding.py:824, in decode(model, mel, options, **kwargs)
#     821 if kwargs:
#     822     options = replace(options, **kwargs)
# --> 824 result = DecodingTask(model, options).run(mel)
#     826 return result[0] if single else result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\decoding.py:737, in DecodingTask.run(self, mel)
#     734 tokens = tokens.repeat_interleave(self.n_group, dim=0).to(audio_features.device)
#     736 # call the main sampling loop
# --> 737 tokens, sum_logprobs, no_speech_probs = self._main_loop(audio_features, tokens)
#     739 # reshape the tensors to have (n_audio, n_group) as the first two dimensions
#     740 audio_features = audio_features[:: self.n_group]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\decoding.py:687, in DecodingTask._main_loop(self, audio_features, tokens)
#     685 try:
#     686     for i in range(self.sample_len):
# --> 687         logits = self.inference.logits(tokens, audio_features)
#     689         if (
#     690             i == 0 and self.tokenizer.no_speech is not None
#     691         ):  # save no_speech_probs
#     692             probs_at_sot = logits[:, self.sot_index].float().softmax(dim=-1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\decoding.py:163, in PyTorchInference.logits(self, tokens, audio_features)
#     159 if tokens.shape[-1] > self.initial_token_length:
#     160     # only need to use the last token except in the first forward pass
#     161     tokens = tokens[:, -1:]
# --> 163 return self.model.decoder(tokens, audio_features, kv_cache=self.kv_cache)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\model.py:211, in TextDecoder.forward(self, x, xa, kv_cache)
#     208 x = x.to(xa.dtype)
#     210 for block in self.blocks:
# --> 211     x = block(x, xa, mask=self.mask, kv_cache=kv_cache)
#     213 x = self.ln(x)
#     214 logits = (
#     215     x @ torch.transpose(self.token_embedding.weight.to(x.dtype), 0, 1)
#     216 ).float()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\model.py:138, in ResidualAttentionBlock.forward(self, x, xa, mask, kv_cache)
#     136 x = x + self.attn(self.attn_ln(x), mask=mask, kv_cache=kv_cache)[0]
#     137 if self.cross_attn:
# --> 138     x = x + self.cross_attn(self.cross_attn_ln(x), xa, kv_cache=kv_cache)[0]
#     139 x = x + self.mlp(self.mlp_ln(x))
#     140 return x
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\model.py:90, in MultiHeadAttention.forward(self, x, xa, mask, kv_cache)
#      87     k = kv_cache[self.key]
#      88     v = kv_cache[self.value]
# ---> 90 wv, qk = self.qkv_attention(q, k, v, mask)
#      91 return self.out(wv), qk
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\whisper\model.py:107, in MultiHeadAttention.qkv_attention(self, q, k, v, mask)
#     104     qk = qk + mask[:n_ctx, :n_ctx]
#     105 qk = qk.float()
# --> 107 w = F.softmax(qk, dim=-1).to(q.dtype)
#     108 return (w @ v).permute(0, 2, 1, 3).flatten(start_dim=2), qk.detach()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\functional.py:1856, in softmax(input, dim, _stacklevel, dtype)
#    1854     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1855 if dtype is None:
# -> 1856     ret = input.softmax(dim)
#    1857 else:
#    1858     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
